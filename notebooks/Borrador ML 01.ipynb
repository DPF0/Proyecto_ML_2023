# %% [markdown]
# ## Introducción
#
# Hay un potencial de ahorro económico en la calefacción de espacios, siempre que se cumplan las premisas de que la calefacción sea eléctrica y la tarifa eléctrica tenga discriminación horaria. El método a emplear sería el encendido del sistema en las horas de menor coste y el aprovechamiento de la inercia térmica de la estancia para mantenerse dentro de la temperatura de confort.
#
# Teniendo en cuenta que, con esta estrategia, el consumo eléctrico aumenta, el ahorro viene dado por la diferencia de precio de la electricidad entre las distintas horas, y no ésta no siempre será suficiente para compensar la mayor cantidad de energía empleada.
#
# Dado que tanto el precio de la electricidad como la temperatura exterior prevista se conocen con una antelación suficiente, es posible hacer la predicción de gasto en calefacción para cada día con estrategias distintas, y obtener la más barata.
#
# Este proyecto trata de generar el modelo para realizar esta predicción para una vivienda en concreto, en base a datos reales recogidos en la misma entre noviembre de 2022 y marzo de 2023. El sistema de calefacción es en base a bomba de calor, y la tarifa eléctrica es la PVPC, con discriminación horaria.

# %% [markdown]
# ## Dataset
#
# Los datos se extraen de una base de datos InfluxDB, mediante las consultas pertinentes, y se vuelcan a un archivo de tipo csv.

# %%
# Importar librerías

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importar datos

df = pd.read_csv('../data/2023-11-18-18-52 Chronograf Data.csv')

# %% [markdown]
# ## EDA / Feature engineering

# %%
df.head()
# Out:
#                             time  kWh.mean_value  °C.mean_value  \
# 0  2022-10-31T00:00:00.000+01:00         541.115      23.550000
# 1  2022-10-31T01:00:00.000+01:00         541.135      23.800000
# 2  2022-10-31T02:00:00.000+01:00         541.155      23.733333
# 3  2022-10-31T03:00:00.000+01:00         541.175      23.800000
# 4  2022-10-31T04:00:00.000+01:00         541.195      23.650000
#
#    °C.mean_value_2  €/kWh.mean_value
# 0             16.3           0.21445
# 1             15.6           0.20656
# 2             15.0           0.17392
# 3             14.8           0.17453
# 4             15.9           0.17423

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3647 entries, 0 to 3646
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   time              3647 non-null   object
#  1   kWh.mean_value    2862 non-null   float64
#  2   °C.mean_value     3581 non-null   float64
#  3   °C.mean_value_2   3382 non-null   float64
#  4   €/kWh.mean_value  3636 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 142.6+ KB

# %%
# Renombrar columnas

df.rename(columns= {'kWh.mean_value': 'kWh', '°C.mean_value': 'temp_int', \
                    '°C.mean_value_2': 'temp_ext', '€/kWh.mean_value': '€/kWh'}, inplace= True)

# %%
# Timestamps a formato tiempo

df['time'] = pd.to_datetime(df['time'], format='%Y-%m-%dT%H:%M:%S.%f%z', utc= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3647 entries, 0 to 3646
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      3647 non-null   datetime64[ns, UTC]
#  1   kWh       2862 non-null   float64
#  2   temp_int  3581 non-null   float64
#  3   temp_ext  3382 non-null   float64
#  4   €/kWh     3636 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(4)
# memory usage: 142.6 KB

# %%
# Tratamiento de NaN (del EDA)

df['€/kWh'].ffill(axis = 0, inplace= True)
df['temp_int'].ffill(axis= 0, inplace= True)
df['temp_ext'].interpolate(method='linear', limit_direction='forward', axis = 0, inplace=True)
df['kWh'].ffill(axis= 0, inplace= True)
df['kWh'].bfill(axis= 0, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3647 entries, 0 to 3646
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      3647 non-null   datetime64[ns, UTC]
#  1   kWh       3647 non-null   float64
#  2   temp_int  3647 non-null   float64
#  3   temp_ext  3647 non-null   float64
#  4   €/kWh     3647 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(4)
# memory usage: 142.6 KB

# %%
# Generar columnas adicionales

df['consumo'] = df['kWh'].diff()
df['€/h'] = df['€/kWh'] * df['consumo']

# %%
# df.set_index('time', inplace= True)

# %%
df.head()
# Out:
#                        time      kWh   temp_int  temp_ext    €/kWh  consumo  \
# 0 2022-10-30 23:00:00+00:00  541.115  23.550000      16.3  0.21445      NaN
# 1 2022-10-31 00:00:00+00:00  541.135  23.800000      15.6  0.20656     0.02
# 2 2022-10-31 01:00:00+00:00  541.155  23.733333      15.0  0.17392     0.02
# 3 2022-10-31 02:00:00+00:00  541.175  23.800000      14.8  0.17453     0.02
# 4 2022-10-31 03:00:00+00:00  541.195  23.650000      15.9  0.17423     0.02
#
#         €/h
# 0       NaN
# 1  0.004131
# 2  0.003478
# 3  0.003491
# 4  0.003485

# %%
df['dia'] = df['time'].dt.date

# %%
df['€/dia'] = df['€/h'].groupby(df['time'].dt.date).transform('sum')

# %%
# Pasar filas a columnas

for i in range(24,0,-1):
    df['t_ext-'+str(i)] = df['temp_ext'].shift(i)

# %%
for i in range(24,0,-1):
    df['t_int-'+str(i)] = df['temp_int'].shift(i)

# %%
for i in range(24,0,-1):
    df['€/kWh-'+str(i)] = df['€/kWh'].shift(i)

# %%
# df.reset_index(inplace= True)

# %%
df2 = df.copy()
# df2 = df.iloc[1::24].copy()
df3 = df.iloc[1::24].copy()

# %%
df2.dropna(axis= 0, how= 'any', inplace= True)
df3.dropna(axis= 0, how= 'any', inplace= True)

# %%
df2.drop(columns=['kWh', 'temp_int', 'temp_ext', '€/kWh', 'consumo', '€/h', 'time'], inplace= True)
df3.drop(columns=['kWh', 'temp_int', 'temp_ext', '€/kWh', 'consumo', '€/h', 'time'], inplace= True)

# %%
df2.set_index('dia', inplace= True)
df3.set_index('dia', inplace= True)

# %%
df2.head()
# Out:
#                €/dia  t_ext-24  t_ext-23  t_ext-22  t_ext-21  t_ext-20  \
# dia
# 2022-10-31  0.025415      16.3      15.6      15.0      14.8      15.9
# 2022-11-01  0.000000      15.6      15.0      14.8      15.9      16.5
# 2022-11-01  0.000000      15.0      14.8      15.9      16.5      16.9
# 2022-11-01  0.000000      14.8      15.9      16.5      16.9      16.3
# 2022-11-01  0.000000      15.9      16.5      16.9      16.3      18.2
#
#             t_ext-19  t_ext-18  t_ext-17  t_ext-16  ...  €/kWh-10  €/kWh-9  \
# dia                                                 ...
# 2022-10-31      16.5      16.9      16.3      18.2  ...   0.22586  0.24425
# 2022-11-01      16.9      16.3      18.2      18.4  ...   0.24425  0.24498
# 2022-11-01      16.3      18.2      18.4      19.2  ...   0.24498  0.31560
# 2022-11-01      18.2      18.4      19.2      19.9  ...   0.31560  0.30708
# 2022-11-01      18.4      19.2      19.9      20.2  ...   0.30708  0.30744
#
#             €/kWh-8  €/kWh-7  €/kWh-6  €/kWh-5  €/kWh-4  €/kWh-3  €/kWh-2  \
# dia
# 2022-10-31  0.24498  0.31560  0.30708  0.30744  0.35719  0.37758  0.30198
# 2022-11-01  0.31560  0.30708  0.30744  0.35719  0.37758  0.30198  0.28566
# 2022-11-01  0.30708  0.30744  0.35719  0.37758  0.30198  0.28566  0.20872
# 2022-11-01  0.30744  0.35719  0.37758  0.30198  0.28566  0.20872  0.19380
# 2022-11-01  0.35719  0.37758  0.30198  0.28566  0.20872  0.19380  0.16898
#
#             €/kWh-1
# dia
# 2022-10-31  0.28566
# 2022-11-01  0.20872
# 2022-11-01  0.19380
# 2022-11-01  0.16898
# 2022-11-01  0.16923
#
# [5 rows x 73 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3623 entries, 2022-10-31 to 2023-03-31
# Data columns (total 73 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   €/dia     3623 non-null   float64
#  1   t_ext-24  3623 non-null   float64
#  2   t_ext-23  3623 non-null   float64
#  3   t_ext-22  3623 non-null   float64
#  4   t_ext-21  3623 non-null   float64
#  5   t_ext-20  3623 non-null   float64
#  6   t_ext-19  3623 non-null   float64
#  7   t_ext-18  3623 non-null   float64
#  8   t_ext-17  3623 non-null   float64
#  9   t_ext-16  3623 non-null   float64
#  10  t_ext-15  3623 non-null   float64
#  11  t_ext-14  3623 non-null   float64
#  12  t_ext-13  3623 non-null   float64
#  13  t_ext-12  3623 non-null   float64
#  14  t_ext-11  3623 non-null   float64
#  15  t_ext-10  3623 non-null   float64
#  16  t_ext-9   3623 non-null   float64
#  17  t_ext-8   3623 non-null   float64
#  18  t_ext-7   3623 non-null   float64
#  19  t_ext-6   3623 non-null   float64
#  20  t_ext-5   3623 non-null   float64
#  21  t_ext-4   3623 non-null   float64
#  22  t_ext-3   3623 non-null   float64
#  23  t_ext-2   3623 non-null   float64
#  24  t_ext-1   3623 non-null   float64
#  25  t_int-24  3623 non-null   float64
#  26  t_int-23  3623 non-null   float64
#  27  t_int-22  3623 non-null   float64
#  28  t_int-21  3623 non-null   float64
#  29  t_int-20  3623 non-null   float64
#  30  t_int-19  3623 non-null   float64
#  31  t_int-18  3623 non-null   float64
#  32  t_int-17  3623 non-null   float64
#  33  t_int-16  3623 non-null   float64
#  34  t_int-15  3623 non-null   float64
#  35  t_int-14  3623 non-null   float64
#  36  t_int-13  3623 non-null   float64
#  37  t_int-12  3623 non-null   float64
#  38  t_int-11  3623 non-null   float64
#  39  t_int-10  3623 non-null   float64
#  40  t_int-9   3623 non-null   float64
#  41  t_int-8   3623 non-null   float64
#  42  t_int-7   3623 non-null   float64
#  43  t_int-6   3623 non-null   float64
#  44  t_int-5   3623 non-null   float64
#  45  t_int-4   3623 non-null   float64
#  46  t_int-3   3623 non-null   float64
#  47  t_int-2   3623 non-null   float64
#  48  t_int-1   3623 non-null   float64
#  49  €/kWh-24  3623 non-null   float64
#  50  €/kWh-23  3623 non-null   float64
#  51  €/kWh-22  3623 non-null   float64
#  52  €/kWh-21  3623 non-null   float64
#  53  €/kWh-20  3623 non-null   float64
#  54  €/kWh-19  3623 non-null   float64
#  55  €/kWh-18  3623 non-null   float64
#  56  €/kWh-17  3623 non-null   float64
#  57  €/kWh-16  3623 non-null   float64
#  58  €/kWh-15  3623 non-null   float64
#  59  €/kWh-14  3623 non-null   float64
#  60  €/kWh-13  3623 non-null   float64
#  61  €/kWh-12  3623 non-null   float64
#  62  €/kWh-11  3623 non-null   float64
#  63  €/kWh-10  3623 non-null   float64
#  64  €/kWh-9   3623 non-null   float64
#  65  €/kWh-8   3623 non-null   float64
#  66  €/kWh-7   3623 non-null   float64
#  67  €/kWh-6   3623 non-null   float64
#  68  €/kWh-5   3623 non-null   float64
#  69  €/kWh-4   3623 non-null   float64
#  70  €/kWh-3   3623 non-null   float64
#  71  €/kWh-2   3623 non-null   float64
#  72  €/kWh-1   3623 non-null   float64
# dtypes: float64(73)
# memory usage: 2.0+ MB

# %%
plt.figure(figsize= (14, 14))
sns.heatmap(df2.corr(), annot= True)
;
# Out:
# ''

# %%
df2.reset_index(inplace= True)
df3.reset_index(inplace= True)

# %%
# Si lo trato como una serie temporal tiene este aspecto

plt.figure(figsize= (14, 5))
plt.plot(df2['dia'], df2['€/dia'])
plt.xlabel('Fecha')
plt.ylabel('Euros')
;
# Out:
# ''

# %%
sns.boxplot(data= df['temp_int'])
;
# Out:
# ''

# %%
df2.drop(columns= 'dia', inplace= True)

# %% [markdown]
# ## Modelos

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split, RandomizedSearchCV
from sklearn.metrics import accuracy_score, recall_score
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor

# %%
X = df2.drop(columns= '€/dia')
Y = df2['€/dia']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.20, random_state= 51)

# %%
X_train.shape
# Out:
# (2898, 72)

# %% [markdown]
# ### Random Forest Regressor

# %%
# Pruebo Random Forest Regressor

r_forest = RandomForestRegressor()

#Parametros a probar en el gridsearch
parameters = {
    'n_estimators': [20, 25, 30, 35, 40, 45, 50],
    'max_depth': [1, 2]
}


#Estimador a probar en el gridsearch
# svc = svm.SVC()

#Creamos el gridsearch
clf = GridSearchCV(estimator = r_forest,
                  param_grid = parameters,
                  n_jobs = 6,
                  cv = 5,
                  scoring= 'neg_mean_absolute_error')

#Entrenamos el gridsearch
clf.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=6,
#              param_grid={'max_depth': [1, 2],
#                          'n_estimators': [20, 25, 30, 35, 40, 45, 50]},
#              scoring='neg_mean_absolute_error')

# %%
clf.best_params_
# Out:
# {'max_depth': 2, 'n_estimators': 45}

# %%
# Random Forest con parámetros optimizados

r_forest = RandomForestRegressor(n_estimators= 40, max_depth= 2)

# %%
r_forest.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=2, n_estimators=40)

# %%
mae_train = mean_absolute_error(Y_train, r_forest.predict(X_train))

mae_train
# Out:
# 0.32643455615044015

# %%
mae_test = mean_absolute_error(Y_test, r_forest.predict(X_test))

mae_test
# Out:
# 0.3401198275015913

# %%
# RMSE train

mean_squared_error(Y_train, r_forest.predict(X_train), squared= False)
# Out:
# 0.4217399260475818

# %%
# RMSE test

mean_squared_error(Y_test, r_forest.predict(X_test), squared= False)
# Out:
# 0.4353792801106466

# %%
mean_absolute_percentage_error(Y_train, r_forest.predict(X_train))
# En este caso MAPE no es útil, porque hay valores de y = 0. En ese caso, MAPE tiende a infinito.
# Out:
# 309025211430024.06

# %% [markdown]
# ### Linear Regression

# %%
# Pruebo una Regresión lineal

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet

# %%
l_reg = LinearRegression()

# %%
l_reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
mean_absolute_error(Y_train, l_reg.predict(X_train))
# Out:
# 0.31565197963951536

# %%
mean_absolute_error(Y_test, l_reg.predict(X_test))
# Out:
# 0.32319589032276136

# %% [markdown]
# ### Lasso

# %%
baseline_error = mean_absolute_error(Y_test, l_reg.predict(X_test))

# %%
# Prueba Lasso

n_alphas = 100
alphas = np.logspace(-4, 3, n_alphas) 

coef_lasso = []
err_lasso = []
baseline = []

for a in alphas:
    lasso = Lasso(alpha=a, max_iter= 100000)
    lasso.fit(X_train, Y_train)
    
    coef_lasso.append(lasso.coef_)
    
    y_pred = lasso.predict(X_test)
    lasso_error = mean_absolute_error(y_pred, Y_test)
    
    err_lasso.append(lasso_error)
    baseline.append(baseline_error)

# %%
plt.figure(figsize=(20,12))
ax = plt.gca()
ax.plot(alphas, err_lasso, linewidth=5, color='red', label="lasso regression")
ax.plot(alphas, baseline, linewidth=4,linestyle='--', color='blue', label='Linear regression')
ax.set_xscale('log')
plt.xlabel('$\lambda$', fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.ylabel('error', fontsize=30)
#plt.ylim(200, 400)
ax.legend(fontsize=30)
plt.title(r'Regression error ($\lambda$)', fontsize=30)
plt.show()

# %% [markdown]
# ### Ridge

# %%
n_alphas = 100
alphas = np.logspace(-4, 3, n_alphas) 

coef_ridge = []
err_ridge = []
baseline = []

for a in alphas:
    ridge = Ridge(alpha=a)
    ridge.fit(X_train, Y_train)
    
    coef_ridge.append(ridge.coef_)
    
    y_pred = ridge.predict(X_test)
    ridge_error = mean_absolute_error(y_pred, Y_test)
    
    err_ridge.append(ridge_error)
    baseline.append(baseline_error)

# %%
plt.figure(figsize=(20,12))
ax = plt.gca()
ax.plot(alphas, err_ridge, linewidth=5, color='red', label="Ridge regression")
ax.plot(alphas, baseline, linewidth=4,linestyle='--', color='blue', label='Linear regression')
ax.set_xscale('log')
plt.xlabel('$\lambda$', fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.ylabel('error', fontsize=30)
# plt.ylim(380, 400)
ax.legend(fontsize=30)
plt.title(r'Regression error ($\lambda$)', fontsize=30)
plt.show()

# %% [markdown]
# ### XGBoost Regressor

# %%
# Pruebo XGBoost

xgboost = XGBRegressor()

#Parametros a probar en el gridsearch
parameters = {
    'n_estimators': [20, 25, 30, 35, 40, 45, 50],
    'max_depth': [1, 2, 3],
    'learning_rate': [0.01, 0.1, 0.2]
}


#Estimador a probar en el gridsearch
# svc = svm.SVC()

#Creamos el gridsearch
clf = GridSearchCV(estimator = xgboost,
                  param_grid = parameters,
                  n_jobs = 6,
                  cv = 5,
                  scoring= 'neg_mean_absolute_error')

#Entrenamos el gridsearch
clf.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=6,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [1, 2, 3],
#                          'n_estimators': [20, 25, 30, 35, 40, 45, 50]},
#              scoring='neg_mean_absolute_error')

# %%
clf.best_params_
# Out:
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 50}

# %%
# XGBoost con mejores parámetros

xgboost = XGBRegressor(n_estimators= 50, max_depth= 3, learning_rate= 0.2)

# %%
xgboost.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=50, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# MAE en train

mean_absolute_error(Y_train, xgboost.predict(X_train))
# Out:
# 0.18155190243746203

# %%
# MAE en test

mean_absolute_error(Y_test, xgboost.predict(X_test))
# Out:
# 0.22077794189735775

# %%
# El resultado de XGBoost en test es el mejor, y el overfitting es aceptable
# Considerando ésto, es el modelo que escojo

# %% [markdown]
# ### ARIMA

# %%
from pmdarima.arima import auto_arima, ARIMA

# %%
df2.head()
# Out:
#       €/dia  t_ext-24  t_ext-23  t_ext-22  t_ext-21  t_ext-20  t_ext-19  \
# 0  0.025415      16.3      15.6      15.0      14.8      15.9      16.5
# 1  0.000000      15.6      15.0      14.8      15.9      16.5      16.9
# 2  0.000000      15.0      14.8      15.9      16.5      16.9      16.3
# 3  0.000000      14.8      15.9      16.5      16.9      16.3      18.2
# 4  0.000000      15.9      16.5      16.9      16.3      18.2      18.4
#
#    t_ext-18  t_ext-17  t_ext-16  ...  €/kWh-10  €/kWh-9  €/kWh-8  €/kWh-7  \
# 0      16.9      16.3      18.2  ...   0.22586  0.24425  0.24498  0.31560
# 1      16.3      18.2      18.4  ...   0.24425  0.24498  0.31560  0.30708
# 2      18.2      18.4      19.2  ...   0.24498  0.31560  0.30708  0.30744
# 3      18.4      19.2      19.9  ...   0.31560  0.30708  0.30744  0.35719
# 4      19.2      19.9      20.2  ...   0.30708  0.30744  0.35719  0.37758
#
#    €/kWh-6  €/kWh-5  €/kWh-4  €/kWh-3  €/kWh-2  €/kWh-1
# 0  0.30708  0.30744  0.35719  0.37758  0.30198  0.28566
# 1  0.30744  0.35719  0.37758  0.30198  0.28566  0.20872
# 2  0.35719  0.37758  0.30198  0.28566  0.20872  0.19380
# 3  0.37758  0.30198  0.28566  0.20872  0.19380  0.16898
# 4  0.30198  0.28566  0.20872  0.19380  0.16898  0.16923
#
# [5 rows x 73 columns]

# %%
train = df2['€/dia'][:-720]
test = df2['€/dia'][-720:]

# %%
model = auto_arima(train,
                   #stock_df['Open'][:1240].values.reshape(-1,1),
                   start_p=1,
                    start_q=1,
                    max_d=3,
                    max_p=5,
                    max_q=5,
                    stationary=False,
                    trace=True,
                    stepwise=True)

print(model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-6462.706, Time=1.10 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-6466.706, Time=0.57 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-6464.706, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-6464.706, Time=0.44 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-6468.690, Time=0.07 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 2.364 seconds
# -6468.6899487329665

# %%
arima_good = ARIMA(order=(0,1,0))
model.fit(train)
print(model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2903
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                3235.345
# Date:                Sun, 26 Nov 2023   AIC                          -6468.690
# Time:                        17:55:21   BIC                          -6462.717
# Sample:                             0   HQIC                         -6466.538
#                                - 2903
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0063   2.34e-05    268.572      0.000       0.006       0.006
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):           1147293.88
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.32   Skew:                             0.82
# Prob(H) (two-sided):                  0.00   Kurtosis:                       100.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
predictions = model.predict(720)
print("mean_absolute_error:", mean_absolute_error(test, predictions))
# Out:
# mean_absolute_error: 0.4366994684635275

# %%
plt.plot(test)
plt.plot(predictions,color='red');

# %%
# En mi opinión, a la vista de la serie temporal (estocástica), ARIMA no es un modelo adecuado
# No tiene en cuenta los factores relevantes: temperaturas, precios
# Por tanto, lo descarto

# %%
X_test.head()
# Out:
#       t_ext-24  t_ext-23  t_ext-22  t_ext-21  t_ext-20  t_ext-19  t_ext-18  \
# 1869       8.7       9.1       9.5      12.3      9.60       9.1      11.9
# 3312      12.7      16.1      15.2      15.1     14.90      14.7      14.5
# 1247      14.2      12.5      12.1      11.5     10.40      12.4      12.3
# 2593       6.2       5.8       4.9       4.6      4.20       3.5       3.8
# 2542      13.2      13.0      12.5      11.1      9.95       8.8      11.0
#
#       t_ext-17  t_ext-16  t_ext-15  ...  €/kWh-10  €/kWh-9  €/kWh-8  €/kWh-7  \
# 1869      12.1     10.70       9.4  ...   0.09714  0.09584  0.09653  0.05086
# 3312      13.0     13.45      15.2  ...   0.12388  0.10782  0.11657  0.14028
# 1247      13.6     16.00      16.4  ...   0.14975  0.10157  0.10357  0.12105
# 2593       3.3      4.20       7.5  ...   0.18705  0.19826  0.21753  0.27290
# 2542       9.0      9.50       9.1  ...   0.23968  0.23627  0.18979  0.19377
#
#       €/kWh-6  €/kWh-5  €/kWh-4  €/kWh-3  €/kWh-2  €/kWh-1
# 1869  0.05094  0.05442  0.05347  0.09723  0.10660  0.11275
# 3312  0.15788  0.17189  0.19097  0.17801  0.17509  0.16209
# 1247  0.12134  0.18311  0.18617  0.18685  0.18467  0.12349
# 2593  0.28410  0.27514  0.26798  0.21351  0.18971  0.16245
# 2542  0.20484  0.21203  0.26909  0.28644  0.28827  0.27578
#
# [5 rows x 72 columns]

# %%
df3.drop(columns= ['dia'], inplace= True)

# %%
df3.head()
# Out:
#       €/dia  t_ext-24  t_ext-23  t_ext-22  t_ext-21  t_ext-20  t_ext-19  \
# 0  0.000000      15.6      15.0      14.8     15.90      16.5      16.9
# 1  0.000000      15.0      14.8      14.6     14.20      14.1      13.8
# 2  0.000000      11.0      10.8      10.6     10.80      10.3       9.9
# 3  0.000000      14.0      13.9      18.0     20.70      17.9      18.7
# 4  0.105214      13.1      13.6      14.1     14.25      14.4      13.7
#
#    t_ext-18  t_ext-17  t_ext-16  ...  €/kWh-10  €/kWh-9  €/kWh-8  €/kWh-7  \
# 0      16.3      18.2     18.40  ...   0.24425  0.24498  0.31560  0.30708
# 1      13.3      13.0     14.10  ...   0.14096  0.15892  0.19475  0.20905
# 2       9.7       9.6     10.25  ...   0.18224  0.20612  0.25624  0.31795
# 3      20.4      20.6     20.10  ...   0.19815  0.20692  0.21203  0.29282
# 4      14.0      13.1     14.30  ...   0.17341  0.20984  0.23515  0.30798
#
#    €/kWh-6  €/kWh-5  €/kWh-4  €/kWh-3  €/kWh-2  €/kWh-1
# 0  0.30744  0.35719  0.37758  0.30198  0.28566  0.20872
# 1  0.20918  0.25116  0.25381  0.21370  0.19894  0.16728
# 2  0.31450  0.32499  0.27735  0.20276  0.18787  0.16115
# 3  0.27084  0.25057  0.24510  0.19544  0.18077  0.20838
# 4  0.35728  0.33038  0.32079  0.26236  0.24619  0.19349
#
# [5 rows x 73 columns]

# %%
# Estos son días naturales, no cualquier período de 24 horas

X_days = df3.drop(columns= ['€/dia'])
Y_days = df3['€/dia']

# %%
# MAE en días naturales con el mejor XGboost

mean_absolute_error(Y_days, xgboost.predict(X_days))
# Out:
# 0.19732353164100463

# %%
# El MAE se mantiene estable, refuerza la idea de que XGboost es un modelo adecuado en esta situación

# %%
plt.figure(figsize= (14, 5))
sns.lineplot(Y_days, color= 'g', label= 'Real')
sns.lineplot(xgboost.predict(X_days), color= 'r', label= 'Predicho')
;
# Out:
# ''

# %% [markdown]
# ## Predicciones de coste con distintas estrategias

# %%
dias_caros = df3.copy()

# %%
dias_caros.loc[:,'t_int-7':'t_int-1'] = 21

# %%
estrategia_1 = xgboost.predict(dias_caros.drop(columns= '€/dia'))

# %%
dias_caros.loc[:,'t_int-9':'t_int-7'] = 23

# %%
dias_caros.loc[:, 't_int-7':'t_int-1'] = 19

# %%
estrategia_2 = xgboost.predict(dias_caros.drop(columns= '€/dia'))

# %%
plt.figure(figsize= (14, 5))
sns.lineplot(estrategia_1, color= 'b')
sns.lineplot(estrategia_2, color= 'r')
;
# Out:
# ''

# %%
euros = estrategia_1 - estrategia_2

# %%
plt.figure(figsize= (14, 5))
sns.lineplot(euros)
;
# Out:
# ''

# %%
estrategia_1.sum()
# Out:
# 91.44858

# %%
estrategia_2.sum()
# Out:
# 118.86423

# %%
dias_caros['€/dia'].sum()
# Out:
# 94.25442384326578
